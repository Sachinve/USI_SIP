# %%
import pandas as pd

# %%
pums14 = pd.read_csv("../Data/PUMs_NY\PUMS_NY_2014\ss14hny.csv",dtype={'PUMA':str})

# %%
pums14.head()
# Out:
#   RT  SERIALNO  DIVISION   PUMA  REGION  ST   ADJHSG   ADJINC  WGTP  NP  \
# 0  H         6         2  03808       1  36  1000000  1008425   631   1
# 1  H         9         2  02300       1  36  1000000  1008425     0   1
# 2  H        44         2  03107       1  36  1000000  1008425   183   3
# 3  H        45         2  04103       1  36  1000000  1008425    59   3
# 4  H        50         2  00100       1  36  1000000  1008425    36   0
#
#     ...    wgtp71  wgtp72  wgtp73  wgtp74  wgtp75 wgtp76  wgtp77  wgtp78  \
# 0   ...      1043     635    1107     916     659    522     597     710
# 1   ...         0       0       0       0       0      0       0       0
# 2   ...       166     379     346      58      60    262     180      51
# 3   ...        19      94      65      59      18     56      16      16
# 4   ...        62      11      31      10      38     33      11      36
#
#    wgtp79  wgtp80
# 0     989     168
# 1       0       0
# 2     282     220
# ...

# %%
wtsum = pums14["WGTP"].sum()
wtsum
# Out:
# 8191528L

# %%
pum_Areas = pums14.groupby("PUMA")

# %%
list(pum_Areas)
# Out:
# [('00100',
#         RT  SERIALNO  DIVISION   PUMA  REGION  ST   ADJHSG   ADJINC  WGTP  NP  \
#   4      H        50         2  00100       1  36  1000000  1008425    36   0
#   502    H      7825         2  00100       1  36  1000000  1008425     0   1
#   608    H      9530         2  00100       1  36  1000000  1008425    37   0
#   618    H      9745         2  00100       1  36  1000000  1008425     0   1
#   678    H     10759         2  00100       1  36  1000000  1008425    31   2
#   878    H     13904         2  00100       1  36  1000000  1008425    45   6
#   950    H     15069         2  00100       1  36  1000000  1008425    26   0
#   958    H     15190         2  00100       1  36  1000000  1008425    31   1
#   961    H     15267         2  00100       1  36  1000000  1008425    36   2
#   997    H     15910         2  00100       1  36  1000000  1008425     0   1
#   1011   H     16170         2  00100       1  36  1000000  1008425    70   1
# ...

# %%
pum_Areas['WGTP'].sum()
# Out:
# PUMA
# 00100    52240
# 00200    96131
# 00300    68026
# 00401    58356
# 00402    70971
# 00403    55851
# 00500    74062
# 00600    53702
# 00701    65264
# 00702    54110
# 00703    69265
# 00704    52213
# 00800    57555
# 00901    57248
# 00902    51719
# 00903    44526
# 00904    55921
# 00905    42696
# 00906    71142
# 01000    44090
# 01101    51280
# 01102    47917
# 01201    50057
# 01202    52389
# 01203    44774
# 01204    73258
# 01205    73529
# 01206    58075
# 01207    69090
# 01300    45353
#          ...
# 04003    57156
# 04004    63398
# 04005    53197
# 04006    56941
# 04007    48905
# 04008    62281
# 04009    73782
# 04010    55178
# 04011    44191
# 04012    48602
# 04013    53964
# 04014    48391
# 04015    63028
# 04016    59036
# 04017    66340
# 04018    50033
# 04101    82347
# 04102    60451
# 04103    97612
# 04104    44839
# 04105    63815
# 04106    58323
# 04107    48400
# 04108    54205
# 04109    56749
# 04110    66431
# 04111    49795
# ...

# %%
puma_nyc = pd.read_csv("../Data/PUMA_NYC/Use_this/PUMA_NYC.txt", dtype={'PUMACE10':str})

# %%
puma_nyc
# Out:
#     FID  STATEFP10 PUMACE10        AFFGEOID10  GEOID10  \
# 0     0         36    04014  7950000US3604014  3604014
# 1     1         36    04006  7950000US3604006  3604006
# 2     2         36    04009  7950000US3604009  3604009
# 3     3         36    03709  7950000US3603709  3603709
# 4     4         36    03807  7950000US3603807  3603807
# 5     5         36    03705  7950000US3603705  3603705
# 6     6         36    04108  7950000US3604108  3604108
# 7     7         36    03701  7950000US3603701  3603701
# 8     8         36    04106  7950000US3604106  3604106
# 9     9         36    03708  7950000US3603708  3603708
# 10   10         36    03803  7950000US3603803  3603803
# 11   11         36    03805  7950000US3603805  3603805
# 12   12         36    03809  7950000US3603809  3603809
# 13   13         36    04013  7950000US3604013  3604013
# 14   14         36    03806  7950000US3603806  3603806
# 15   15         36    04011  7950000US3604011  3604011
# ...

# %%
mums14nyc = pd.merge(pums14,puma_nyc, how='inner', left_on='PUMA',right_on='PUMACE10')

# %%
len(mums14nyc)
# Out:
# 31174

# %%
mums14nyc['WGTP'].sum()
# Out:
# 3438742L

# %% [markdown]
# ### Households!!!
